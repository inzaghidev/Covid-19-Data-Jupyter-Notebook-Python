# %% [markdown]
# # Notes
#
# Merupakan Data Statistik COVID-19 yang pernah di-Update selama 3 Tahun terakhir (2020-2023) di Inzaghi's Blog (Legacy) dan Inzaghi's Sites (Google Sites). Data Statistik COVID-19 ini akan dibuat dengan menggunakan Python di Jupyter Notebook, dan ditampikan di Google Colab. Untuk Source Code dari Program ini, akan disimpan di GitHub Inzaghi's Dev.
#
# Untuk Laman ini, dikhususkan untuk Data Statistik COVID-19 di Seluruh Dunia. Sumber Data untuk COVID-19 Seluruh Dunia :
# - https://www.worldometers.info/coronavirus
# - https://ncov2019.live
# - https://ourworldindata.org/covid-vaccinations
#
# **Project by Inzaghi's Blog, Inzaghi's Sites, and Inzaghi's Dev.**

# %% [markdown]
# # Kurva COVID-19 Spreadsheets
#
# Indonesia : https://docs.google.com/spreadsheets/d/1LfZ0MzwjKfDwXFw_yxqw78UuDnWEi0F9/edit#gid=1317209968
# \
# Seluruh Dunia : https://docs.google.com/spreadsheets/d/1tWFtz3tJlceUsbbC02LbFeD8IFUGbWPT/edit#gid=892898073

# %% [markdown]
# # Data COVID-19 di Seluruh Dunia

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %% [markdown]
# ## Data Kasus COVID-19 di Seluruh Dunia

# %%
cases_data_worldwide = pd.read_csv('./csv/covid-19_data_cases_worldwide.csv')

# %%
cases_data_worldwide.head()
# Out:
#   tanggal_masehi tanggal_hijriah  confirmed_cases   deaths  recoveries  \
# 0    23 Mar 2020     28 Rjb 1441           475310      NaN         NaN
# 1    24 Mar 2020     29 Rjb 1441           522499  20028.0    109291.0
# 2    25 Mar 2020     30 Rjb 1441           573860  22684.0    115343.0
# 3    26 Mar 2020      1 Syb 1441           636182  25889.0    125626.0
# 4    27 Mar 2020      2 Syb 1441           704116  29520.0    135749.0
#
#    active_cases  passive_cases  add_conf_cases  add_deaths  add_recoveries  \
# 0           NaN            NaN           44166        1998            3354
# 1      393180.0       129319.0           47189        2580            6911
# 2      435833.0       138027.0           51361        2656            6052
# 3      484667.0       151515.0           62322        3205           10283
# 4      538847.0       165269.0           67934        3631           10123
#
#    ...  percent_deaths  percent_recov  percent_active  percent_passive  \
# ...

# %%
cases_data_worldwide.head(50)
# Out:
#    tanggal_masehi tanggal_hijriah  confirmed_cases    deaths  recoveries  \
# 0     23 Mar 2020     28 Rjb 1441           475310       NaN         NaN
# 1     24 Mar 2020     29 Rjb 1441           522499   20028.0    109291.0
# 2     25 Mar 2020     30 Rjb 1441           573860   22684.0    115343.0
# 3     26 Mar 2020      1 Syb 1441           636182   25889.0    125626.0
# 4     27 Mar 2020      2 Syb 1441           704116   29520.0    135749.0
# 5     28 Mar 2020      3 Syb 1441           772297   33501.0    147014.0
# 6     29 Mar 2020      4 Syb 1441           833785   37267.0    158852.0
# 7     30 Mar 2020      5 Syb 1441           898523   41786.0    174626.0
# 8     31 Mar 2020      6 Syb 1441           976318   46768.0    192577.0
# 9      1 Apr 2020      7 Syb 1441          1055362   52296.0    213368.0
# 10     2 Apr 2020      8 Syb 1441          1135344   58843.0    238395.0
# 11     3 Apr 2020      9 Syb 1441          1222987   65367.0    264918.0
# ...

# %%
dates_every_90_days_greg = cases_data_worldwide['tanggal_masehi'][::90]
dates_every_90_days_hijri = cases_data_worldwide['tanggal_hijriah'][::90]

# %% [markdown]
# ### Jumlah Kasus COVID-19 di Seluruh Dunia

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['confirmed_cases'], label='Confirmed Cases', color='#CCFF66')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['deaths'], label='Death Cases', color='red')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['recoveries'], label='Recoveried Cases', color='green')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['active_cases'], label='Active Cases', color='blue')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['passive_cases'], label='Passive Cases', color='orange')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['confirmed_cases'], label='Confirmed Cases', color='#CCFF66')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['deaths'], label='Death Cases', color='red')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['recoveries'], label='Recoveried Cases', color='green')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['active_cases'], label='Active Cases', color='blue')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['passive_cases'], label='Passive Cases', color='orange')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['confirmed_cases'], label='Confirmed Cases', color='#CCFF66')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Konfirmasi COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['confirmed_cases'], label='Confirmed Cases', color='#CCFF66')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Konfirmasi COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['deaths'], label='Death Cases', color='red')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Kematian COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['deaths'], label='Death Cases', color='red')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Kematian COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['recoveries'], label='Recoveried Cases', color='green')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Kesembuhan COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['recoveries'], label='Recoveried Cases', color='green')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Kesembuhan COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['active_cases'], label='Active Cases', color='blue')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Aktif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['active_cases'], label='Active Cases', color='blue')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Aktif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['passive_cases'], label='Passive/Outcome Cases', color='orange')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Pasif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['passive_cases'], label='Passive/Outcome Cases', color='orange')
plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Kasus Pasif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %% [markdown]
# ### Penambahan Kasus COVID-19 di Seluruh Dunia

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_conf_cases'], label='Additional Confirmed Cases', color='#CCFF66')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_deaths'], label='Additional Death Cases', color='red')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_recoveries'], label='Additional Recoveried Cases', color='green')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_active_cases'], label='Additional Active Cases', color='blue')
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_passive_cases'], label='Additional Passive Cases', color='orange')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_conf_cases'], label='Additional Confirmed Cases', color='#CCFF66')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_deaths'], label='Additional Death Cases', color='red')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_recoveries'], label='Additional Recoveried Cases', color='green')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_active_cases'], label='Additional Active Cases', color='blue')
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_passive_cases'], label='Additional Passive Cases', color='orange')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_conf_cases'], label='Additional Confirmed Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Konfirmasi COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_conf_cases'], label='Additional Confirmed Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Konfirmasi COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}K'.format(x * 1e-3)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_deaths'], label='Additional Death Cases', color='red')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Ribu)')
plt.title('Kurva Penambahan Kasus Kematian COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}K'.format(x * 1e-3)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_deaths'], label='Additional Death Cases', color='red')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Ribu)')
plt.title('Kurva Penambahan Kasus Kematian COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_recoveries'], label='Additional Recoveried Cases', color='green')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Pulih COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_recoveries'], label='Additional Recoveried Cases', color='green')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Pulih COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_active_cases'], label='Additional Active Cases', color='blue')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Aktif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_active_cases'], label='Additional Active Cases', color='blue')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Aktif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_masehi'], cases_data_worldwide['add_passive_cases'], label='Additional Passive Cases', color='orange')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Pasif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(cases_data_worldwide['tanggal_hijriah'], cases_data_worldwide['add_passive_cases'], label='Additional Passive Cases', color='orange')

plt.xlabel('Date')
plt.ylabel('Jumlah Kasus (Juta)')
plt.title('Kurva Penambahan Kasus Pasif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %% [markdown]
# ### Persentase Kasus COVID-19 di Seluruh Dunia

# %% [markdown]
# ## Data Testing COVID-19 Seluruh Dunia

# %%
tests_data_worldwide = pd.read_csv('./csv/covid-19_data_tests_worldwide.csv')

# %%
tests_data_worldwide.head()
# Out:
#   tanggal_masehi tanggal_hijriah   tested  negative_cases  positive_cases  \
# 0    23 Mar 2020     28 Rjb 1441  4491039         4015729          475310
# 1    24 Mar 2020     29 Rjb 1441  4708373         4185874          522499
# 2    25 Mar 2020     30 Rjb 1441  4949571         4375711          573860
# 3    26 Mar 2020      1 Syb 1441  5225650         4589468          636182
# 4    27 Mar 2020      2 Syb 1441  5523603         4819487          704116
#
#    add_testing  add_negative  add_positive  percent_negative  \
# 0       193045        148879         44166          0.894165
# 1       217334        170145         47189          0.889028
# 2       241198        189837         51361          0.884059
# 3       276079        213757         62322          0.878258
# 4       297953        230019         67934          0.872526
#
#    percent_positive  negative_test_rate  positive_test_rate  negativity_rate  \
# ...

# %%
tests_data_worldwide.head(50)
# Out:
#    tanggal_masehi tanggal_hijriah    tested  negative_cases  positive_cases  \
# 0     23 Mar 2020     28 Rjb 1441   4491039         4015729          475310
# 1     24 Mar 2020     29 Rjb 1441   4708373         4185874          522499
# 2     25 Mar 2020     30 Rjb 1441   4949571         4375711          573860
# 3     26 Mar 2020      1 Syb 1441   5225650         4589468          636182
# 4     27 Mar 2020      2 Syb 1441   5523603         4819487          704116
# 5     28 Mar 2020      3 Syb 1441   5805788         5033491          772297
# 6     29 Mar 2020      4 Syb 1441   6110020         5276235          833785
# 7     30 Mar 2020      5 Syb 1441   6356914         5458391          898523
# 8     31 Mar 2020      6 Syb 1441   6652690         5676372          976318
# 9      1 Apr 2020      7 Syb 1441   7127195         6071833         1055362
# 10     2 Apr 2020      8 Syb 1441   7631758         6496414         1135344
# ...

# %%
dates_every_90_days_greg = tests_data_worldwide['tanggal_masehi'][::90]
dates_every_90_days_hijri = tests_data_worldwide['tanggal_hijriah'][::90]

# %% [markdown]
# ### Jumlah Tes COVID-19 di Seluruh Dunia

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['tested'], label='People Tested', color='#26AAA7')
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['negative_cases'], label='Negative Cases', color='#D5D045')
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['positive_cases'], label='Positive Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Miliar)')
plt.title('Kurva Testing COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['tested'], label='People Tested', color='#26AAA7')
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['negative_cases'], label='Negative Cases', color='#D5D045')
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['positive_cases'], label='Positive Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Miliar)')
plt.title('Kurva Testing COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['tested'], label='People Tested', color='#26AAA7')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Miliar)')
plt.title('Jumlah Test COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['tested'], label='People Tested', color='#26AAA7')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Miliar)')
plt.title('Jumlah Test COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['negative_cases'], label='Negative Cases', color='#D5D045')
plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Miliar)')
plt.title('Jumlah Kasus Negatif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['negative_cases'], label='Negative Cases', color='#D5D045')
plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Miliar)')
plt.title('Jumlah Kasus Negatif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['negative_cases'], label='Negative Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Jumlah Kasus Positif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['negative_cases'], label='Negative Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Jumlah Kasus Positif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %% [markdown]
# ### Penambahan Testing COVID-19 di Seluruh Dunia

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['add_testing'], label='Additional Tests', color='#26AAA7')
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['add_negative'], label='Additional Negative Cases', color='#D5D045')
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['add_positive'], label='Additional Positive Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Jumlah Testing COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['add_testing'], label='Additional Tests', color='#26AAA7')
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['add_negative'], label='Additional Negative Cases', color='#D5D045')
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['add_positive'], label='Additional Positive Cases', color='#CCFF66')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Jumlah Testing COVID-19 di Seluruh Dunia (Tanggal Hjiriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['add_testing'], label='Additional Tests', color='#26AAA7')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Jumlah Tes COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['add_testing'], label='Additional Tests', color='#26AAA7')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Jumlah Tes COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['add_negative'], label='Additional Negative Cases', color='#D5D045')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Kasus Negatif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['add_negative'], label='Additional Negative Cases', color='#D5D045')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Kasus Negatif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_masehi'], tests_data_worldwide['add_positive'], label='Additional Positive Cases', color='#D5D045')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Kasus Positif COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}M'.format(x * 1e-6)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(tests_data_worldwide['tanggal_hijriah'], tests_data_worldwide['add_positive'], label='Additional Positive Cases', color='#D5D045')

plt.xlabel('Date')
plt.ylabel('Jumlah Tes (Juta)')
plt.title('Kurva Penambahan Kasus Positif COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %% [markdown]
# ### Persentase Testing COVID-19 di Seluruh Dunia

# %% [markdown]
# ## Data Vaksinasi COVID-19 Seluruh Dunia

# %%
vaccine_data_worldwide = pd.read_csv('./csv/covid-19_data_vaccine_worldwide.csv')

# %%
vaccine_data_worldwide.head()
# Out:
#   tanggal_masehi tanggal_hijriah  total_vacc  vacc_doses1  vacc_doses2  \
# 0    15 Des 2020     30 RAk 1442       28506        28506          NaN
# 1    16 Des 2020      1 JMw 1442       28506        28506          NaN
# 2    17 Des 2020      2 JMw 1442       28506        28506          NaN
# 3    18 Des 2020      3 JMw 1442       28506        28506          NaN
# 4    19 Des 2020      4 JMw 1442       28567        28567          NaN
#
#    vacc_doses3  add_total_vacc  add_vacc_doses1  add_vacc_doses2  \
# 0          NaN           28500            28500              NaN
# 1          NaN               0                0              NaN
# 2          NaN               0                0              NaN
# 3          NaN               0                0              NaN
# 4          NaN              61               61              NaN
#
#    add_vacc_doses3  percent_doses1  percent_doses2  percent_doses3  \
# 0              NaN             1.0             NaN             NaN
# ...

# %%
vaccine_data_worldwide.head(50)
# Out:
#    tanggal_masehi tanggal_hijriah  total_vacc  vacc_doses1  vacc_doses2  \
# 0     15 Des 2020     30 RAk 1442       28506        28506          NaN
# 1     16 Des 2020      1 JMw 1442       28506        28506          NaN
# 2     17 Des 2020      2 JMw 1442       28506        28506          NaN
# 3     18 Des 2020      3 JMw 1442       28506        28506          NaN
# 4     19 Des 2020      4 JMw 1442       28567        28567          NaN
# 5     20 Des 2020      5 JMw 1442      592134       592134          NaN
# 6     21 Des 2020      6 JMw 1442      674926       674926          NaN
# 7     22 Des 2020      7 JMw 1442      743044       743044          NaN
# 8     23 Des 2020      8 JMw 1442     1238755      1238755          NaN
# 9     24 Des 2020      9 JMw 1442     1326582      1326582          NaN
# 10    25 Des 2020     10 JMw 1442     1370278      1370278          NaN
# 11    26 Des 2020     11 JMw 1442     2343563      2343563          NaN
# ...

# %%
dates_every_90_days_greg = vaccine_data_worldwide['tanggal_masehi'][::90]
dates_every_90_days_hijri = vaccine_data_worldwide['tanggal_hijriah'][::90]

# %% [markdown]
# ### Jumlah Vaksinasi COVID-19 di Seluruh Dunia

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(vaccine_data_worldwide['tanggal_masehi'], vaccine_data_worldwide['total_vacc'], label='People Tested', color='#95CBA1')
plt.plot(vaccine_data_worldwide['tanggal_masehi'], vaccine_data_worldwide['vacc_doses1'], label='Negative Cases', color='#00D998')
plt.plot(vaccine_data_worldwide['tanggal_masehi'], vaccine_data_worldwide['vacc_doses2'], label='Negative Cases', color='#A5A5A5')
plt.plot(vaccine_data_worldwide['tanggal_masehi'], vaccine_data_worldwide['vacc_doses3'], label='Positive Cases', color='#9BC2E6')

plt.xlabel('Date')
plt.ylabel('Jumlah Vaksinasi (Miliar)')
plt.title('Kurva Vaksinasi COVID-19 di Seluruh Dunia (Tanggal Masehi)')
plt.legend()
plt.xticks(dates_every_90_days_greg, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()

# %%
# Define the function to convert numbers to millions format
def millions_format(x, pos):
    'The two args are the value and tick position'
    return '{:1.1f}B'.format(x * 1e-9)

# Step 2: Create the plot
plt.figure(figsize=(10, 6))
plt.plot(vaccine_data_worldwide['tanggal_hijriah'], vaccine_data_worldwide['total_vacc'], label='People Tested', color='#95CBA1')
plt.plot(vaccine_data_worldwide['tanggal_hijriah'], vaccine_data_worldwide['vacc_doses1'], label='Negative Cases', color='#00D998')
plt.plot(vaccine_data_worldwide['tanggal_hijriah'], vaccine_data_worldwide['vacc_doses2'], label='Negative Cases', color='#A5A5A5')
plt.plot(vaccine_data_worldwide['tanggal_hijriah'], vaccine_data_worldwide['vacc_doses3'], label='Positive Cases', color='#9BC2E6')

plt.xlabel('Date')
plt.ylabel('Jumlah Vaksinasi (Miliar)')
plt.title('Kurva Vaksinasi COVID-19 di Seluruh Dunia (Tanggal Hijriah)')
plt.legend()
plt.xticks(dates_every_90_days_hijri, rotation=45)  # Set the x-axis ticks to the dates every 100 days

# Format the y-axis labels in millions format
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(millions_format))

plt.show()
